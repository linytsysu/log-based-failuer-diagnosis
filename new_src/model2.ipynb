# %%
import gc
import numpy as np
import pandas as pd
from gensim.models.word2vec import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import KFold, GroupKFold, StratifiedKFold, StratifiedGroupKFold
from sklearn.utils.class_weight import compute_class_weight
from catboost import CatBoostClassifier, CatBoostRegressor
import lightgbm as lgb
from tqdm import tqdm

import optuna
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# %%
df_train1 = pd.read_csv('train1.csv', dtype={'server_model': 'str',
                                             'last_msg_id': 'str',
                                             'last_template_id': 'str'})
df_test1 = pd.read_csv('test1.csv', dtype={'server_model': 'str',
                                           'last_msg_id': 'str',
                                           'last_template_id': 'str'})

df_train2 = pd.read_csv('train2.csv', dtype={'tmp_appearance_1': 'str',
                                             'tmp_appearance_2': 'str',
                                             'tmp_appearance_3': 'str',
                                             'msg_appearance_1': 'str',
                                             'msg_appearance_2': 'str',
                                             'msg_appearance_3': 'str',
                                             'max_continuous_msg': 'str'})
df_test2 = pd.read_csv('test2.csv', dtype={'tmp_appearance_1': 'str',
                                           'tmp_appearance_2': 'str',
                                           'tmp_appearance_3': 'str',
                                           'msg_appearance_1': 'str',
                                           'msg_appearance_2': 'str',
                                           'msg_appearance_3': 'str',
                                           'max_continuous_msg': 'str'})

df_train3 = pd.read_csv('train3.csv')
df_test3 = pd.read_csv('test3.csv')

df_train4 = pd.read_csv('train4.csv')
df_test4 = pd.read_csv('test4.csv')

df_train5 = pd.read_csv('train5.csv')
df_test5 = pd.read_csv('test5.csv')

df_train6 = pd.read_csv('train_helper.csv')
df_test6 = pd.read_csv('test_helper.csv')

# df_train7 = pd.read_csv('train7.csv')
# df_test7 = pd.read_csv('test7.csv')

df_train = pd.merge(df_train1, df_train2, on=['sn', 'fault_time', 'label'])\
    .merge(df_train3, on=['sn', 'fault_time', 'label'])\
    .merge(df_train4, on=['sn', 'fault_time', 'label'])\
    .merge(df_train5, on=['sn', 'fault_time', 'label'])\
    .merge(df_train6, on=['sn', 'fault_time', 'label'])
df_test = pd.merge(df_test1, df_test2, on=['sn', 'fault_time'])\
    .merge(df_test3, on=['sn', 'fault_time'])\
    .merge(df_test4, on=['sn', 'fault_time'])\
    .merge(df_test5, on=['sn', 'fault_time'])\
    .merge(df_test6, on=['sn', 'fault_time'])

# %%
df_train.shape, df_test.shape
# Out:
# ((16604, 124), (3030, 123))

# %%
bert_train = pd.read_csv('../bert/train.csv')
bert_test = pd.read_csv('../bert/test_b.csv')

df_train = pd.concat([df_train, bert_train.iloc[:, 9:]], axis=1)
df_test = pd.concat([df_test, bert_test.iloc[:, 9:]], axis=1)

# df_train = df_train.merge(bert_train, on=['sn', 'fault_time', 'label'])
# df_test = df_test.merge(bert_test, on=['sn', 'fault_time'])

# %%
df_train.shape, df_test.shape
# Out:
# ((16604, 508), (3030, 507))

# %%
for name in ['last_msg_id', 'last_template_id', 'tmp_appearance_1', 'tmp_appearance_2', 'tmp_appearance_3',
             'msg_appearance_1', 'msg_appearance_2', 'msg_appearance_3', 'max_continuous_msg']:
    df_train[name] = df_train[name].fillna('NULL')
    df_test[name] = df_test[name].fillna('NULL')

# %%
def cat_model_train(x_train, y_train, x_val, y_val):
    NUM_CLASSES = y_train.nunique()
    classes = np.unique(y_train)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))
    params = { 
        'task_type': 'CPU',
        'bootstrap_type': 'Bernoulli',
        'learning_rate': 0.03, 
        'eval_metric': 'MultiClass', 
        'loss_function': 'MultiClass', 
        'classes_count': NUM_CLASSES, 
        'iterations': 10000,
        'random_state': 42,
        'depth': 8,
        'leaf_estimation_iterations': 8,
        'reg_lambda': 5,
        'subsample': 0.8,
        'class_weights': class_weights,
        'early_stopping_rounds': 100,
        'cat_features': ['server_model', 'last_msg_id', 'last_template_id',
                         'tmp_appearance_1', 'tmp_appearance_2', 'tmp_appearance_3',
                         'msg_appearance_1', 'msg_appearance_2', 'msg_appearance_3',
                         'max_continuous_msg'],
    }
    model = CatBoostClassifier(**params)
    model.fit(x_train, 
               y_train, 
               eval_set=(x_val, y_val), 
               verbose=100)
    return model

# %%
# NUM_CLASSES = df_train['pre_label'].nunique()
# FOLDS = 10
# use_features = [col for col in df_train.columns if col not in ['sn', 'fault_time', 'label', 'pre_label']]

# target = TARGET
# y_pred = np.zeros((len(df_test), NUM_CLASSES))

FOLDS = 10
target = 'label'
use_features = [col for col in df_train.columns if col not in ['sn', 'fault_time', target]]
oof_pred = np.zeros((len(df_train),))

y_pred1 = np.zeros((len(df_test), 3))
y_pred2 = np.zeros((len(df_test), 2))

folds = GroupKFold(n_splits=FOLDS)
for fold, (tr_ind, val_ind) in enumerate(folds.split(df_train, df_train['label'], df_train['sn'])):
    df_trian_sub = df_train.iloc[tr_ind].copy()
    df_valid_sub = df_train.iloc[val_ind].copy()
    
    x_train1, x_val1 = df_trian_sub[use_features], df_valid_sub[use_features]
    y_train1, y_val1 = df_trian_sub[target], df_valid_sub[target]
    y_train1 = y_train1.apply(lambda x: 0 if x <= 1 else x-1)
    y_val1 = y_val1.apply(lambda x: 0 if x <= 1 else x-1)
    model1 = cat_model_train(x_train1, y_train1, x_val1, y_val1)

    x_train2, x_val2 = df_trian_sub[df_trian_sub['label'] <= 1][use_features], \
                       df_valid_sub[df_valid_sub['label'] <= 1][use_features]
    y_train2, y_val2 = df_trian_sub[df_trian_sub['label'] <= 1][target],\
                       df_valid_sub[df_valid_sub['label'] <= 1][target]
    model2 = cat_model_train(x_train2, y_train2, x_val2, y_val2)
    
    y_pred1 += model1.predict_proba(df_test[use_features]) / folds.n_splits
    y_pred2 += model2.predict_proba(df_test[use_features]) / folds.n_splits

    val_pred = []
    val_proba = model1.predict_proba(x_val1)
    for i in range(val_proba.shape[0]):
        if np.argmax(val_proba[i]) == 0:
            proba = model2.predict_proba([x_val1.iloc[i]])
            val_pred.append(np.argmax(proba[0]))
        else:
            val_pred.append(np.argmax(val_proba[i])+1)

    score = f1_score(df_valid_sub[target], val_pred, average='macro')
    print(f'F1 score: {score}')

    oof_pred[val_ind] = val_pred
# Out:
# 0:	learn: 1.0479539	test: 1.0485107	best: 1.0485107 (0)	total: 302ms	remaining: 50m 15s
# 100:	learn: 0.2347191	test: 0.2806276	best: 0.2806276 (100)	total: 25.7s	remaining: 42m 2s
# 200:	learn: 0.1767513	test: 0.2539307	best: 0.2539307 (200)	total: 50.8s	remaining: 41m 14s
# 300:	learn: 0.1443985	test: 0.2420481	best: 0.2420188 (293)	total: 1m 15s	remaining: 40m 44s
# 400:	learn: 0.1221294	test: 0.2364505	best: 0.2362845 (399)	total: 1m 40s	remaining: 40m 6s
# 500:	learn: 0.1064826	test: 0.2331059	best: 0.2331059 (500)	total: 2m 5s	remaining: 39m 34s
# 600:	learn: 0.0950628	test: 0.2305399	best: 0.2305399 (600)	total: 2m 29s	remaining: 39m 3s
# 700:	learn: 0.0850522	test: 0.2293919	best: 0.2293899 (699)	total: 2m 54s	remaining: 38m 35s
# 800:	learn: 0.0759342	test: 0.2293046	best: 0.2290562 (744)	total: 3m 19s	remaining: 38m 11s
# 900:	learn: 0.0692346	test: 0.2281656	best: 0.2281525 (887)	total: 3m 44s	remaining: 37m 44s
# 1000:	learn: 0.0634907	test: 0.2274431	best: 0.2271995 (994)	total: 4m 8s	remaining: 37m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2271994758
# bestIteration = 994
#
# Shrink model to first 995 iterations.
# 0:	learn: 0.6882356	test: 0.6888866	best: 0.6888866 (0)	total: 204ms	remaining: 34m 4s
# 100:	learn: 0.5031503	test: 0.6044148	best: 0.6043243 (99)	total: 28.2s	remaining: 46m 5s
# 200:	learn: 0.4288245	test: 0.5968007	best: 0.5967137 (198)	total: 56.5s	remaining: 45m 52s
# 300:	learn: 0.3709095	test: 0.6024896	best: 0.5965554 (202)	total: 1m 24s	remaining: 45m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.59655543
# bestIteration = 202
#
# Shrink model to first 203 iterations.
# F1 score: 0.7481160666697191
# 0:	learn: 1.0471020	test: 1.0466809	best: 1.0466809 (0)	total: 250ms	remaining: 41m 37s
# 100:	learn: 0.2346493	test: 0.2853582	best: 0.2853582 (100)	total: 25.8s	remaining: 42m 4s
# 200:	learn: 0.1770728	test: 0.2571672	best: 0.2571672 (200)	total: 50.9s	remaining: 41m 19s
# 300:	learn: 0.1434846	test: 0.2467287	best: 0.2467287 (300)	total: 1m 16s	remaining: 40m 54s
# 400:	learn: 0.1222559	test: 0.2411177	best: 0.2411177 (400)	total: 1m 41s	remaining: 40m 18s
# 500:	learn: 0.1060444	test: 0.2399693	best: 0.2397448 (487)	total: 2m 5s	remaining: 39m 43s
# 600:	learn: 0.0936541	test: 0.2380726	best: 0.2380726 (600)	total: 2m 30s	remaining: 39m 16s
# 700:	learn: 0.0836502	test: 0.2381762	best: 0.2375535 (682)	total: 2m 55s	remaining: 38m 47s
# 800:	learn: 0.0750251	test: 0.2380516	best: 0.2374545 (717)	total: 3m 20s	remaining: 38m 22s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2374544878
# bestIteration = 717
#
# Shrink model to first 718 iterations.
# 0:	learn: 0.6882240	test: 0.6888991	best: 0.6888991 (0)	total: 201ms	remaining: 33m 25s
# 100:	learn: 0.5005742	test: 0.6099957	best: 0.6099957 (100)	total: 28.1s	remaining: 45m 54s
# 200:	learn: 0.4275297	test: 0.6075755	best: 0.6070999 (149)	total: 56.3s	remaining: 45m 43s
# 300:	learn: 0.3717548	test: 0.6047605	best: 0.6043589 (291)	total: 1m 24s	remaining: 45m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6043589295
# bestIteration = 291
#
# Shrink model to first 292 iterations.
# F1 score: 0.7527123278472583
# 0:	learn: 1.0483254	test: 1.0488660	best: 1.0488660 (0)	total: 252ms	remaining: 42m 4s
# 100:	learn: 0.2340883	test: 0.2987178	best: 0.2987178 (100)	total: 25.5s	remaining: 41m 41s
# 200:	learn: 0.1776097	test: 0.2684855	best: 0.2684855 (200)	total: 50.5s	remaining: 41m 3s
# 300:	learn: 0.1447387	test: 0.2585390	best: 0.2584285 (296)	total: 1m 15s	remaining: 40m 28s
# 400:	learn: 0.1235397	test: 0.2522101	best: 0.2522101 (400)	total: 1m 40s	remaining: 39m 54s
# 500:	learn: 0.1077790	test: 0.2494717	best: 0.2494717 (500)	total: 2m 4s	remaining: 39m 28s
# 600:	learn: 0.0948597	test: 0.2473335	best: 0.2473112 (593)	total: 2m 29s	remaining: 38m 59s
# 700:	learn: 0.0838578	test: 0.2453551	best: 0.2453449 (699)	total: 2m 54s	remaining: 38m 32s
# 800:	learn: 0.0745808	test: 0.2449637	best: 0.2449475 (799)	total: 3m 19s	remaining: 38m 5s
# 900:	learn: 0.0675075	test: 0.2446338	best: 0.2442726 (877)	total: 3m 43s	remaining: 37m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2442726361
# bestIteration = 877
#
# Shrink model to first 878 iterations.
# 0:	learn: 0.6877400	test: 0.6899619	best: 0.6899619 (0)	total: 204ms	remaining: 34m
# 100:	learn: 0.5005777	test: 0.6064356	best: 0.6064356 (100)	total: 28s	remaining: 45m 44s
# 200:	learn: 0.4251789	test: 0.6094132	best: 0.6058118 (109)	total: 55.8s	remaining: 45m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6058117976
# bestIteration = 109
#
# Shrink model to first 110 iterations.
# F1 score: 0.761354546170709
# 0:	learn: 1.0494117	test: 1.0507392	best: 1.0507392 (0)	total: 248ms	remaining: 41m 24s
# 100:	learn: 0.2340538	test: 0.2973682	best: 0.2973682 (100)	total: 25.7s	remaining: 42m
# 200:	learn: 0.1767462	test: 0.2728845	best: 0.2728845 (200)	total: 51s	remaining: 41m 25s
# 300:	learn: 0.1440322	test: 0.2661881	best: 0.2661421 (297)	total: 1m 15s	remaining: 40m 44s
# 400:	learn: 0.1228317	test: 0.2617014	best: 0.2617014 (400)	total: 1m 40s	remaining: 40m 9s
# 500:	learn: 0.1069713	test: 0.2601444	best: 0.2599863 (498)	total: 2m 5s	remaining: 39m 37s
# 600:	learn: 0.0943937	test: 0.2592337	best: 0.2591322 (550)	total: 2m 30s	remaining: 39m 8s
# 700:	learn: 0.0845145	test: 0.2598930	best: 0.2590153 (657)	total: 2m 55s	remaining: 38m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2590153054
# bestIteration = 657
#
# Shrink model to first 658 iterations.
# 0:	learn: 0.6889513	test: 0.6895235	best: 0.6895235 (0)	total: 204ms	remaining: 34m 1s
# 100:	learn: 0.5089954	test: 0.5946690	best: 0.5938813 (95)	total: 28.1s	remaining: 45m 49s
# 200:	learn: 0.4327271	test: 0.5933348	best: 0.5896454 (143)	total: 55.9s	remaining: 45m 23s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.5896453683
# bestIteration = 143
#
# Shrink model to first 144 iterations.
# F1 score: 0.7641023881807687
# 0:	learn: 1.0533797	test: 1.0538355	best: 1.0538355 (0)	total: 249ms	remaining: 41m 28s
# 100:	learn: 0.2364996	test: 0.2829588	best: 0.2829588 (100)	total: 25.7s	remaining: 41m 54s
# 200:	learn: 0.1777133	test: 0.2567078	best: 0.2567078 (200)	total: 51s	remaining: 41m 28s
# 300:	learn: 0.1447294	test: 0.2454794	best: 0.2454794 (300)	total: 1m 15s	remaining: 40m 46s
# 400:	learn: 0.1221387	test: 0.2401207	best: 0.2401207 (400)	total: 1m 40s	remaining: 40m 11s
# 500:	learn: 0.1065102	test: 0.2374948	best: 0.2374292 (497)	total: 2m 5s	remaining: 39m 39s
# 600:	learn: 0.0939049	test: 0.2348556	best: 0.2348556 (600)	total: 2m 30s	remaining: 39m 11s
# 700:	learn: 0.0833825	test: 0.2348712	best: 0.2344198 (631)	total: 2m 55s	remaining: 38m 44s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2344198068
# bestIteration = 631
#
# Shrink model to first 632 iterations.
# 0:	learn: 0.6885813	test: 0.6893941	best: 0.6893941 (0)	total: 205ms	remaining: 34m 5s
# 100:	learn: 0.5024036	test: 0.6051348	best: 0.6051333 (99)	total: 28.1s	remaining: 45m 49s
# 200:	learn: 0.4239581	test: 0.6059065	best: 0.6031835 (125)	total: 55.8s	remaining: 45m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6031835231
# bestIteration = 125
#
# Shrink model to first 126 iterations.
# F1 score: 0.7624978821799988
# 0:	learn: 1.0517635	test: 1.0527936	best: 1.0527936 (0)	total: 253ms	remaining: 42m 9s
# 100:	learn: 0.2397822	test: 0.2653967	best: 0.2653967 (100)	total: 25.9s	remaining: 42m 18s
# 200:	learn: 0.1814074	test: 0.2330784	best: 0.2330481 (199)	total: 51s	remaining: 41m 24s
# 300:	learn: 0.1477823	test: 0.2198077	best: 0.2198077 (300)	total: 1m 15s	remaining: 40m 46s
# 400:	learn: 0.1249368	test: 0.2127901	best: 0.2127561 (399)	total: 1m 40s	remaining: 40m 11s
# 500:	learn: 0.1088956	test: 0.2083969	best: 0.2083969 (500)	total: 2m 5s	remaining: 39m 39s
# 600:	learn: 0.0956348	test: 0.2068480	best: 0.2068408 (594)	total: 2m 30s	remaining: 39m 18s
# 700:	learn: 0.0848301	test: 0.2063139	best: 0.2061425 (631)	total: 2m 55s	remaining: 38m 49s
# 800:	learn: 0.0765467	test: 0.2050264	best: 0.2049796 (775)	total: 3m 20s	remaining: 38m 27s
# 900:	learn: 0.0692598	test: 0.2050445	best: 0.2047518 (828)	total: 3m 45s	remaining: 38m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2047518293
# bestIteration = 828
#
# Shrink model to first 829 iterations.
# 0:	learn: 0.6880499	test: 0.6903182	best: 0.6903182 (0)	total: 208ms	remaining: 34m 43s
# 100:	learn: 0.4990982	test: 0.6217801	best: 0.6212837 (71)	total: 28.3s	remaining: 46m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6212837375
# bestIteration = 71
#
# Shrink model to first 72 iterations.
# F1 score: 0.7625589640305165
# 0:	learn: 1.0509393	test: 1.0506798	best: 1.0506798 (0)	total: 251ms	remaining: 41m 46s
# 100:	learn: 0.2376207	test: 0.2616295	best: 0.2616295 (100)	total: 25.5s	remaining: 41m 38s
# 200:	learn: 0.1797480	test: 0.2296123	best: 0.2296123 (200)	total: 50.4s	remaining: 40m 58s
# 300:	learn: 0.1477616	test: 0.2177186	best: 0.2177186 (300)	total: 1m 15s	remaining: 40m 27s
# 400:	learn: 0.1255110	test: 0.2092933	best: 0.2092933 (400)	total: 1m 40s	remaining: 40m 3s
# 500:	learn: 0.1087514	test: 0.2047540	best: 0.2047540 (500)	total: 2m 5s	remaining: 39m 31s
# 600:	learn: 0.0959017	test: 0.2025699	best: 0.2024587 (591)	total: 2m 29s	remaining: 39m 1s
# 700:	learn: 0.0856294	test: 0.1998520	best: 0.1998061 (699)	total: 2m 54s	remaining: 38m 33s
# 800:	learn: 0.0764349	test: 0.1993760	best: 0.1991045 (745)	total: 3m 19s	remaining: 38m 5s
# 900:	learn: 0.0688588	test: 0.1983575	best: 0.1983362 (896)	total: 3m 44s	remaining: 37m 44s
# 1000:	learn: 0.0626660	test: 0.1973781	best: 0.1973676 (999)	total: 4m 8s	remaining: 37m 18s
# 1100:	learn: 0.0577591	test: 0.1972569	best: 0.1970853 (1075)	total: 4m 33s	remaining: 36m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1970853068
# bestIteration = 1075
#
# Shrink model to first 1076 iterations.
# 0:	learn: 0.6888119	test: 0.6903135	best: 0.6903135 (0)	total: 222ms	remaining: 37m
# 100:	learn: 0.5015068	test: 0.6338392	best: 0.6333030 (82)	total: 28.1s	remaining: 45m 49s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.633303012
# bestIteration = 82
#
# Shrink model to first 83 iterations.
# F1 score: 0.7390027876702931
# 0:	learn: 1.0529298	test: 1.0535408	best: 1.0535408 (0)	total: 249ms	remaining: 41m 29s
# 100:	learn: 0.2392810	test: 0.2760525	best: 0.2760525 (100)	total: 25.5s	remaining: 41m 42s
# 200:	learn: 0.1804145	test: 0.2430449	best: 0.2430449 (200)	total: 50.5s	remaining: 41m 4s
# 300:	learn: 0.1477154	test: 0.2292295	best: 0.2292295 (300)	total: 1m 15s	remaining: 40m 31s
# 400:	learn: 0.1259414	test: 0.2207981	best: 0.2207981 (400)	total: 1m 40s	remaining: 39m 58s
# 500:	learn: 0.1082662	test: 0.2162427	best: 0.2160844 (489)	total: 2m 5s	remaining: 39m 33s
# 600:	learn: 0.0959176	test: 0.2136859	best: 0.2136094 (599)	total: 2m 29s	remaining: 39m 2s
# 700:	learn: 0.0850684	test: 0.2114893	best: 0.2113314 (692)	total: 2m 54s	remaining: 38m 33s
# 800:	learn: 0.0764567	test: 0.2101123	best: 0.2101123 (800)	total: 3m 19s	remaining: 38m 7s
# 900:	learn: 0.0695168	test: 0.2093146	best: 0.2090979 (884)	total: 3m 43s	remaining: 37m 41s
# 1000:	learn: 0.0635650	test: 0.2092348	best: 0.2090972 (930)	total: 4m 9s	remaining: 37m 19s
# 1100:	learn: 0.0581780	test: 0.2092587	best: 0.2088208 (1066)	total: 4m 33s	remaining: 36m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2088207865
# bestIteration = 1066
#
# Shrink model to first 1067 iterations.
# 0:	learn: 0.6884208	test: 0.6891304	best: 0.6891304 (0)	total: 208ms	remaining: 34m 38s
# 100:	learn: 0.5062406	test: 0.5866983	best: 0.5866983 (100)	total: 28s	remaining: 45m 45s
# 200:	learn: 0.4284471	test: 0.5746831	best: 0.5742198 (192)	total: 55.8s	remaining: 45m 18s
# 300:	learn: 0.3695296	test: 0.5761240	best: 0.5738465 (252)	total: 1m 23s	remaining: 44m 59s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.5738464825
# bestIteration = 252
#
# Shrink model to first 253 iterations.
# F1 score: 0.7885734580548701
# 0:	learn: 1.0532515	test: 1.0543747	best: 1.0543747 (0)	total: 247ms	remaining: 41m 5s
# 100:	learn: 0.2339070	test: 0.2977975	best: 0.2977975 (100)	total: 25.7s	remaining: 41m 54s
# 200:	learn: 0.1768249	test: 0.2701208	best: 0.2701208 (200)	total: 50.7s	remaining: 41m 13s
# 300:	learn: 0.1450604	test: 0.2619753	best: 0.2619753 (300)	total: 1m 15s	remaining: 40m 39s
# 400:	learn: 0.1221687	test: 0.2563619	best: 0.2561386 (397)	total: 1m 40s	remaining: 40m 17s
# 500:	learn: 0.1067114	test: 0.2536920	best: 0.2535642 (498)	total: 2m 5s	remaining: 39m 39s
# 600:	learn: 0.0947831	test: 0.2537788	best: 0.2531097 (528)	total: 2m 30s	remaining: 39m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.2531096629
# bestIteration = 528
#
# Shrink model to first 529 iterations.
# 0:	learn: 0.6887256	test: 0.6890065	best: 0.6890065 (0)	total: 205ms	remaining: 34m 12s
# 100:	learn: 0.4984498	test: 0.6170737	best: 0.6163988 (96)	total: 28.1s	remaining: 45m 52s
# 200:	learn: 0.4234376	test: 0.6120928	best: 0.6108360 (183)	total: 56.3s	remaining: 45m 43s
# 300:	learn: 0.3678868	test: 0.6177313	best: 0.6107848 (214)	total: 1m 23s	remaining: 45m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6107847962
# bestIteration = 214
#
# Shrink model to first 215 iterations.
# F1 score: 0.7577597481026482
# 0:	learn: 1.0521784	test: 1.0524796	best: 1.0524796 (0)	total: 248ms	remaining: 41m 20s
# 100:	learn: 0.2358982	test: 0.2916776	best: 0.2916776 (100)	total: 25.6s	remaining: 41m 50s
# 200:	learn: 0.1791487	test: 0.2642148	best: 0.2642148 (200)	total: 50.7s	remaining: 41m 10s
# 300:	learn: 0.1448490	test: 0.2551289	best: 0.2551289 (300)	total: 1m 15s	remaining: 40m 43s
# 400:	learn: 0.1224990	test: 0.2482243	best: 0.2481518 (398)	total: 1m 40s	remaining: 40m 13s
# 500:	learn: 0.1063441	test: 0.2462350	best: 0.2459413 (486)	total: 2m 5s	remaining: 39m 41s
# 600:	learn: 0.0932741	test: 0.2453873	best: 0.2453175 (599)	total: 2m 30s	remaining: 39m 10s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.245317504
# bestIteration = 599
#
# Shrink model to first 600 iterations.
# 0:	learn: 0.6885950	test: 0.6897006	best: 0.6897006 (0)	total: 208ms	remaining: 34m 41s
# 100:	learn: 0.4970436	test: 0.6246755	best: 0.6246755 (100)	total: 28.4s	remaining: 46m 19s
# 200:	learn: 0.4216933	test: 0.6204280	best: 0.6194330 (175)	total: 56.3s	remaining: 45m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.619432969
# bestIteration = 175
#
# Shrink model to first 176 iterations.
# F1 score: 0.7468240983584353

# %%
from sklearn.metrics import classification_report
print(classification_report(df_train[target], oof_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.50      0.49      1476
#            1       0.73      0.72      0.73      3387
#            2       0.96      0.94      0.95      9320
#            3       0.83      0.91      0.87      2421
#
#     accuracy                           0.85     16604
#    macro avg       0.75      0.77      0.76     16604
# weighted avg       0.85      0.85      0.85     16604

# %%
def macro_f1(y_true, y_pred) -> float:
    """
    计算得分
    :param target_df: [sn,fault_time,label]
    :param submit_df: [sn,fault_time,label]
    :return:
    """
    weights =  [3  /  7,  2  /  7,  1  /  7,  1  /  7]
    overall_df = pd.DataFrame([y_true, y_pred]).T
    overall_df.columns = ['label_gt', 'label_pr']

    macro_F1 =  0.
    for i in  range(len(weights)):
        TP =  len(overall_df[(overall_df['label_gt'] == i) & (overall_df['label_pr'] == i)])
        FP =  len(overall_df[(overall_df['label_gt'] != i) & (overall_df['label_pr'] == i)])
        FN =  len(overall_df[(overall_df['label_gt'] == i) & (overall_df['label_pr'] != i)])
        precision = TP /  (TP + FP)  if  (TP + FP)  >  0  else  0
        recall = TP /  (TP + FN)  if  (TP + FP)  >  0  else  0
        F1 =  2  * precision * recall /  (precision + recall)  if  (precision + recall)  >  0  else  0
        macro_F1 += weights[i]  * F1
    return macro_F1

macro_f1(df_train[target], oof_pred)
# Out:
# 0.6764523238103658

# %%
y_pred = []
for i in range(y_pred1.shape[0]):
    if np.argmax(y_pred1[i]) == 0:
        proba = y_pred2[i]
        y_pred.append(np.argmax(proba))
    else:
        y_pred.append(np.argmax(y_pred1[i])+1)

# %%
submit_df = pd.read_csv('../data/preliminary_submit_dataset_b.csv')

sub = submit_df[['sn', 'fault_time']].copy()
sub['label'] = y_pred
display(sub.head())
sub['label'].value_counts() / sub.shape[0]
# Out:
#              sn           fault_time  label
# 0  0015fe530ad4  2020-05-01 23:48:17      2
# 1  00380f1435b0  2020-07-28 07:51:13      3
# 2  0045a71d0221  2020-07-02 06:33:54      1
# 3  004d5a7954e7  2020-08-24 08:27:55      2
# 4  004d5a7954e7  2020-08-24 09:42:45      1
# 2    0.527723
# 3    0.202640
# 1    0.180198
# 0    0.089439
# Name: label, dtype: float64

# %%
label1 = pd.read_csv('../data/preliminary_train_label_dataset.csv')
label2 = pd.read_csv('../data/preliminary_train_label_dataset_s.csv')
label_df = pd.concat([label1, label2]).reset_index(drop=True)
label_df = label_df.drop_duplicates().reset_index(drop=True)

label_df['label'].value_counts() / label_df.shape[0]
# Out:
# 2    0.561311
# 1    0.203987
# 3    0.145808
# 0    0.088894
# Name: label, dtype: float64

# %%
sub.to_csv('baseline3_gkf_sn_new.csv', index=False)
